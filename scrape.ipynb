# %%
import pandas as pd
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

youtube = build('youtube', 'v3', developerKey="AIzaSyCtEXObNEafYof0XpO9dNlBPuz3mOkZYyc")

def get_comments_df(video_id):
    comments_list = []
    
    try:
        # Initial request
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100, # Max allowed is 100
            textFormat="plainText"
        )
        
        while request:
            response = request.execute()

            for item in response['items']:
                snippet = item['snippet']['topLevelComment']['snippet']
                comments_list.append({
                    'author': snippet['authorDisplayName'],
                    'text': snippet['textDisplay'],
                    'likes': snippet['likeCount'],
                    'published_at': snippet['publishedAt']
                })
            
            # This automatically handles the nextPageToken for you
            request = youtube.commentThreads().list_next(request, response)
            
            # Optional: Break if you reach your desired cap (e.g., 10,000)
            if len(comments_list) >= 10000:
                break

        return pd.DataFrame(comments_list)

    except HttpError as e:
        print(f"Error: {e}")
        return pd.DataFrame()
# Out:
# c:\Users\Admin\anaconda3\envs\learn-env\lib\site-packages\google\api_core\_python_version_support.py:246: FutureWarning: You are using a non-supported Python version (3.8.5). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# c:\Users\Admin\anaconda3\envs\learn-env\lib\site-packages\google\auth\__init__.py:52: FutureWarning: You are using a Python version 3.8 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.8"), FutureWarning)
# ...

# %%
dataset2= get_comments_df('lBZgfmNRGR8')
dataset2
# Out:
#                   author                                               text  \
# 0              @omwami-j                                       Subscribe ❤🙏
# 1        @LAKACHELAKACHE  😂😂😂😂Yani place ilifanyiwa ni ya kitajiri but i...
# 2            @Mwikalip68                             Hiii ni saw❤❤❤❤❤❤🎉🎉🎉🎉🎉
# 3    @LilianKemuto-q9v8u  Kwa harusi hakunanga rules hiyo ni siku yako n...
# 4              @bela-063                                        Riswa riswa
# ..                   ...                                                ...
# 224          @lous-pr1xq                                    This was crazy😂
# 225         @NaomiMbulwa  Weeeee🎉 upcoming YouTubers gather here nipitie...
# 226      @geoffreymanthi                                Rich people problem
# 227         @BonnieWahiu  Tunangoja pedi alete mali kumbe msee anashikan...
# 228             @Mr_Mugz                            kama si hivi heri ikae😅
#
#      likes          published_at
# ...

# %%
dataset2.to_csv('Dataset2.csv')

# %%
### Generate dataset 3 
dataset3= get_comments_df('XYCmzUYAbHQ')
dataset3
# Out:
#                      author  \
# 0            @ObinnaTVExtra
# 1        @stephenmosage7468
# 2        @stephenmosage7468
# 3                   @pn5003
# 4           @ruthogando6029
# ...                     ...
# 2565  @sphinicanyangara7761
# 2566      @phyllismoraa3210
# 2567      @Vivonjenga-tu9vf
# 2568        @norahkendi5990
# 2569       @LeahNjeri-hu9gs
#
#                                                    text  likes  \
# 0                     Who do you want on the next show?    237
# 1                        Yaani usherati mnarembesha ivi      0
# 2     Dhen saii 2026 .... Bibi ya zakayo kashika usu...      0
# 3     😂😂culture heee ziii ... He is never serious my...      0
# 4                Imagine Sasa watoto wao wakiona hizi 😢      0
# ...                                                 ...    ...
# 2565                  Bur dawa ya prevention SI ya cure      0
# 2566  We love sabrinah  acha hannah  analeta results...      3
# ...

# %%
dataset3.to_csv('dataset3.csv')

# %%
dataset4 = get_comments_df('y5GmEWWLV-s')
dataset4
# Out:
#                        author  \
# 0            @emilybosire5253
# 1         @TeresiaNjeri-jj1jp
# 2         @TeresiaNjeri-jj1jp
# 3               @JOHNTHUO-w9d
# 4         @UwinezaAline-em2ue
# ...                       ...
# 1687         @nyokskinyah8246
# 1688  @EmmanuelNyongesa-y9i6t
# 1689            @Victoria-254
# 1690        @RuthMogire-k4e1u
# 1691        @maureenomega6535
#
#                                                    text  likes  \
# 0                    Is this real ama content creation?      0
# 1         Sasa huyu anajifanya mwanaume na ananyesha tu      0
# 2                 Wenye wanapiga ngemi shetani awalinde      0
# 3                        I rebuke this   in Jesus name.      0
# 4                                       Iy ni film 😅😅😅😅      0
# ...                                                 ...    ...
# 1687  Na mzee koko akakukumbalia haya🤔aki I pity the...     10
# 1688  Bonveee Kwan kunaendaje umeamua kutuletea lesb...      1
# ...

# %%
dataset4= get_comments_df('0SVqoFUEdN8')
dataset4
# Out:
#                      author  \
# 0            @theeplutoshow
# 1     @josephatmonyenye4479
# 2               @GlennTonne
# 3           @Archi.Giovanna
# 4          @EvansWambua-t8e
# ...                     ...
# 1486         @findingian001
# 1487        @salmamirugi129
# 1488     @estherwanjiru2740
# 1489              @purity..
# 1490      @eunicestasha9319
#
#                                                    text  likes  \
# 0     THEE PLUTO INSPIRES. https://youtu.be/ypJ0cxfH...    334
# 1     kuna mahali Pluto huwa unasahau "TIKITOK " mam...      0
# 2     Atii Bro codeee 😢😢😢 walahii minakukata shingo ...      0
# 3     Niko hapa 2026😅hii nayo ilikuwa out of the nor...      0
# 4     bros comes before hoes...........my G did the ...      0
# ...                                                 ...    ...
# 1486                            Humans became wicked !!     11
# 1487        Wakwanza aki nipeni likes atakama. Ni 20 tu   1465
# ...

# %%
dataset4.to_csv('Dataset4.csv')

# %%
dataset5= get_comments_df('WSKL2Ed7KxQ')
dataset5
# Out:
#                  author                                      text  likes  \
# 0            @dmjus6782               uyo bestie wa hio term.....      0
# 1             @brad4683                            sandra anaweza      0
# 2           @massyuhuru                        ZINGINE N PERSONAL      0
# 3    @PeterlewisKingori             Pole kwa huyo jamaa wa kamasi      0
# 4            @Mr.k17551                                  😅 what 😨      0
# ..                  ...                                       ...    ...
# 407             @Gee586                              Kali sana🔥🔥🔥      2
# 408   @eugineomondi6394                       🎉ni kumoto manzee 😂      2
# 409        @maxthuo7444               Never missed any premier ❤❤      8
# 410        @Meshmabumba  Hatulali until we get our daily dose💉❤❤❤     13
# 411  @flirty_angelo4335  Acha nitoe stress za Arsenal uku atleast      9
#
#              published_at
# 0    2026-01-04T15:09:17Z
# 1    2026-01-01T19:09:45Z
# ...

# %%
dataset5.to_csv('dataset5.csv')

# %%
### Merging the csv files 
# Explicitly list your filenames
file_list = ['Dataset1.csv', 'Dataset2.csv', 'dataset3.csv', 'youtube_comments.csv','Dataset4.csv','dataset5.csv','Data5.csv']

# Create an empty list to store the dataframes
data_frames = []

for file in file_list:
    df = pd.read_csv(file)
    # Optional: add a 'category' column so you know where the data came from
    data_frames.append(df)

# Merge them all
final_df = pd.concat(data_frames, ignore_index=True)

# %% [markdown]
# DATA LABELING ATTEMPT

# %%
final_df.to_csv('final_data.csv')

# %%
final_df.head(50)
# Out:
#                   author                                               text  \
# 0   @ChristineArumba-y7q                                          🤣🤣🤣🤣🤣🤣🤣🤣🤣
# 1            @LexiSumaii                             OBina suffer alot 😂😂😂😂
# 2       @marthaayuma7065                 Mmmmh makubwa yapo njiani yanakuja
# 3         @danwenger1113       Tunataka \nKiss between \n\nSalet and Onjiri
# 4         @emmambuvi9029                         Foolishness and witchcraft
# 5     @stephenmuange2998                                      Nipee mate ×2
# 6       @careyochogo7069                                     he is cheating
# 7        @Cherryclover35  Amesema in my HEARTs kwani ako na ngapi anigaw...
# 8         @MochacheJanet                                               😂😂😂😂
# 9         @YvonneKashish               Niruhusi nikuchape pusuu a roho😂😂😂😂😂
# 10     @abdisalangure616  Rubbish this is not only  immoral but also una...
# ...
